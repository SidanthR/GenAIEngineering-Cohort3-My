# %% [markdown]
# #### Relevant Imports

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.types import (
    Integer, Float, String, DateTime, Boolean
)
import pandas as pd
import os

# %%
# Map pandas dtypes to SQLAlchemy types
def map_dtype(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return Integer()
    elif pd.api.types.is_float_dtype(dtype):
        return Float()
    elif pd.api.types.is_bool_dtype(dtype):
        return Boolean()
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return DateTime()
    else:
        return String()  # Default for string

# %% [markdown]
# >Load the CSV file into a pandas data frame
# >data frame reads with the relevant types. If needed it can be adjusted (number, date etc)
# >mapping can be done to SQLAlchemy

# %%
# Load CSV into DataFrame
csv_file = 'Student_Personal_Details.csv'
Data = pd.read_csv(csv_file)
print (Data.dtypes)
# Out:
# student_id      object
# Student Name    object
# Address Line    object
# City            object
# Country         object
# E Mail          object
# dtype: object

# %%
# Create SQLite engine using SQLAlchemy
DB_File = "Sample_2 - Copy.db"

if os.path.exists (DB_File):
    sql_engine = create_engine("sqlite:///"+DB_File)
    # conn_1 = sql_engine.connect ()
else:
    print ("DB Files does not exist")

# %% [markdown]
# >mapping of types

# %%
# Build SQLAlchemy type mapping
sql_types = {col: map_dtype(dtype) for col, dtype in Data.dtypes.items()}
print (sql_types)
# Out:
# {'student_id': String(), 'Student Name': String(), 'Address Line': String(), 'City': String(), 'Country': String(), 'E Mail': String()}

# %% [markdown]
# >Use pandas method to ingest the data into DB
# >Since it is done via sqlalchemy, it can be used for any DB that is linked

# %%
# There is an engine instance created, which can handle multiple connetions
DB_File = "Sample_1 - Copy.db"

if os.path.exists (DB_File):
    sql_engine = create_engine("sqlite:///"+DB_File)
    conn_1 = sql_engine.connect ()
else:
    print ("DB Files does not exist")

# %%
# Write to table using  SQLAlchemy types
table_name = 'Student_Details'
Data.to_sql(table_name, con=sql_engine, if_exists='replace', index=False, dtype=sql_types)
# Out:
# 1000

# %% [markdown]
# >Check if the data is persisting in the database

# %%
# Launch a query on newly created table
conn = sql_engine.connect ()

Result = conn.execute (text("select * from Student_Details limit 10"))

for row in Result:
    print (row)
# Out:
# ('S1000', 'Marie Jimenez', '15664 Angela Well', 'West Ashley', 'Bangladesh', 'shelby67@berg-lucas.com')
# ('S1001', 'Julie Ali', '00495 Dennis Square', 'New Sarah', 'Netherlands', 'kenneth02@wilson.com')
# ('S1002', 'Brian Yang', '100 Meyers Roads', 'South Shelley', 'Benin', 'johnsonsherri@gmail.com')
# ('S1003', 'Nicole Johnson', '277 Austin Pines', 'Stewarttown', 'Nauru', 'lallen@morris.net')
# ('S1004', 'Casey Morris', '42181 Miguel Vista', 'Lake Ericborough', 'Egypt', 'yschmidt@gmail.com')
# ('S1005', 'William Patterson', '91839 Collins Parkways Apt. 069', 'South Regina', 'Montserrat', 'davisjeanette@miller.com')
# ('S1006', 'Nicole Williams', '956 Shields Light', 'South Joseph', 'Italy', 'jhood@gmail.com')
# ('S1007', 'Michael Morse', '12485 Destiny Row Suite 371', 'Amyborough', 'Japan', 'vmercado@gmail.com')
# ('S1008', 'Dale Villarreal', '3376 Christine Track Suite 892', 'East Stephenchester', 'Palau', 'gracefuller@gmail.com')
# ('S1009', 'Kayla Perkins', '932 Andersen Fields Suite 627', 'Bakermouth', 'Antigua and Barbuda', 'thompsonlisa@stevens.info')
